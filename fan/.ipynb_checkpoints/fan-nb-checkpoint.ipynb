# %%
from fan_class import FaceLandmarks
from PIL import Image, ImageDraw

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
# load view image, create box variables (coords from mtcnn-nb)
test_im = Image.open('./photo.jpg')
test_im = test_im.rotate(-90)
test_im = test_im.resize((test_im.width//6, test_im.height//6))
test_npim = np.array(test_im)
plt.imshow(test_im)
box = [(184.16228, 106.84072, 321.80414, 307.66556)]
plt.imshow(test_im)

# %%
box = [184.16228, 106.84072, 321.80414, 307.66556]
fa = FaceLandmarks(
    image = test_npim,
    box = box,
    device='cpu'
)

# %%
ldmk = fa.get_landmarks()
ldmk = ldmk[0]
print(ldmk)
# Out:
# [[178. 189.]
#  [181. 211.]
#  [183. 230.]
#  [186. 246.]
#  [191. 265.]
#  [205. 282.]
#  [216. 292.]
#  [229. 301.]
#  [254. 309.]
#  [278. 303.]
#  [292. 295.]
#  [303. 287.]
#  [314. 271.]
#  [322. 252.]
#  [324. 233.]
#  [327. 214.]
#  [327. 195.]
#  [191. 173.]
#  [202. 170.]
#  [216. 168.]
#  [227. 168.]
#  [238. 170.]
#  [276. 173.]
#  [286. 170.]
#  [297. 168.]
#  [308. 170.]
#  [316. 176.]
#  [257. 195.]
#  [257. 208.]
#  [257. 219.]
#  [257. 230.]
#  [243. 238.]
#  [248. 241.]
#  [257. 241.]
#  [262. 241.]
#  [267. 238.]
#  [208. 192.]
#  [216. 187.]
#  [227. 187.]
#  [235. 192.]
#  [227. 195.]
#  [216. 195.]
#  [276. 192.]
#  [284. 189.]
#  [295. 189.]
#  [303. 192.]
#  [295. 198.]
#  [284. 198.]
#  [227. 263.]
#  [238. 260.]
#  [251. 255.]
#  [257. 257.]
#  [262. 255.]
#  [273. 260.]
#  [284. 263.]
#  [273. 268.]
#  [265. 274.]
#  [257. 274.]
#  [246. 271.]
#  [238. 268.]
#  [229. 263.]
#  [248. 263.]
#  [257. 263.]
#  [262. 263.]
#  [281. 263.]
#  [262. 263.]
#  [254. 263.]
#  [248. 263.]]

# %%
# draw dots with PIL
def draw_dots(image, dot_list, col):
    
    for i in dot_list:
        i = i.flatten().astype(int)
        x0 = i[0] - 1
        y0 = i[1] + 1
        x1 = i[0] + 1
        y1 = i[1] - 1
        newim = ImageDraw.Draw(image)
        newim.rectangle((x0,y0,x1,y1), fill=col)
    
draw_dots(test_im, ldmk, col='red')
plt.imshow(test_im)
